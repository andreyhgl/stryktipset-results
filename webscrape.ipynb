# %%
from bs4 import BeautifulSoup
import urllib3

# %%
url = "https://spela.svenskaspel.se/stryktipset/resultat/2024-12-07/statistik"

print(f"\n ~~~ scraping URL ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
print(f" {url}\n")
# Out:
#  ~~~ scraping URL ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  https://spela.svenskaspel.se/stryktipset/resultat/2024-12-07/statistik

# %%
# Extract the html page
page = urllib3.request("GET", url)
soup = BeautifulSoup(page.data, 'html.parser')

print(f"\n Status code: {page.status}\n")
print(f" ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")

# locate the 'td' element
#interests = soup.find_all('td', attrs={'class':'JustifyLeft'})
# Out:
#  Status code: 200
#
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
#tmp = soup.find_all('a', attrs={'class':'pg_coupon_static__event_desc'})
tmp = soup.find_all('div', {'id':'onboarding_content'})
print(tmp)
# Out:
# []
